# %%
import random
from collections import Counter
import nltk
import matplotlib.pyplot as plt
import re
from re import RegexFlag
from wordcloud import WordCloud 
import sys
import numpy as np
sys.path.append('../preprocess')
from preprocess import load_data
import seaborn as sns
from scipy.special import gammaln, digamma
from nltk.corpus import stopwords

# %%
class LDA_VB:
    def __init__(self, num_topics, alpha=0.05, beta=0.01, max_iter=100, tolerance=1e-5):
        self.K = num_topics  # number of topics
        self.alpha = alpha   # Dirichlet prior on document-topic distributions
        self.beta = beta     # Dirichlet prior on topic-word distributions
        self.max_iter = max_iter
        self.tolerance = tolerance
        
    def fit(self, docs, vocab):
        # Initialize variables
        self.D = len(docs)  # number of documents
        self.V = len(vocab)  # vocabulary size
        self.vocab = vocab
        
        # Initialize variational parameters
        # phi: document-word-topic distribution (D x N x K)
        self.phi = [np.random.dirichlet(np.ones(self.K), size=len(doc)) for doc in docs]
        # gamma: document-topic distribution (D x K)
        self.gamma = np.random.gamma(100., 1./100., (self.D, self.K))
        # beta: topic-word distribution (K x V)
        self.lambda_param = np.random.gamma(100., 1./100., (self.K, self.V))
        
        # Convert documents to word indices
        self.word_ids = [[vocab.index(word) for word in doc] for doc in docs]
        
        # Run variational EM
        old_likelihood = -np.inf
        for iteration in range(self.max_iter):
            # E-step
            self._e_step(docs)
            
            # M-step
            self._m_step(docs)
            
            # Compute likelihood
            likelihood = self._compute_likelihood(docs)
            print(f"Iteration {iteration}: likelihood = {likelihood}")
            
            # Check convergence
            if abs(likelihood - old_likelihood) < self.tolerance:
                break
            old_likelihood = likelihood
            
    def _e_step(self, docs):
        # Update phi and gamma for each document
        for d, doc in enumerate(docs):
            # Initialize gamma for this document
            self.gamma[d] = self.alpha + np.zeros(self.K)
            
            # Update phi and gamma until convergence
            for _ in range(20):  # max inner iterations
                # Update phi
                for n, word_id in enumerate(self.word_ids[d]):
                    log_phi = np.log(self.lambda_param[:, word_id]) + \
                             digamma(self.gamma[d]) - digamma(np.sum(self.gamma[d]))
                    log_phi = log_phi - np.max(log_phi)  # numerical stability
                    self.phi[d][n] = np.exp(log_phi)
                    self.phi[d][n] = self.phi[d][n] / np.sum(self.phi[d][n])
                
                # Update gamma
                self.gamma[d] = self.alpha + np.sum(self.phi[d], axis=0)
                
    def _m_step(self, docs):
        # Update lambda (topic-word distribution)
        self.lambda_param = np.zeros((self.K, self.V)) + self.beta
        for d, doc in enumerate(docs):
            for n, word_id in enumerate(self.word_ids[d]):
                self.lambda_param[:, word_id] += self.phi[d][n]
                
    def _compute_likelihood(self, docs):
        likelihood = 0
        
        # Add E[log p(theta | alpha) - log q(theta | gamma)]
        likelihood += np.sum(
            (self.alpha - self.gamma) * digamma(self.gamma) -
            gammaln(self.alpha) + gammaln(self.gamma)
        )
        
        # Add E[log p(z | theta) - log q(z | phi)]
        for d, doc in enumerate(docs):
            digamma_gamma = digamma(self.gamma[d])  # Calculate once
            digamma_sum = digamma(np.sum(self.gamma[d]))  # Calculate once
            likelihood += np.sum(
                self.phi[d] * (digamma_gamma - digamma_sum)
            )
            likelihood -= np.sum(self.phi[d] * np.log(self.phi[d] + 1e-100))
            
        return likelihood

    def get_topic_words(self, n_words=10):
        # Get the top words for each topic
        topic_words = []
        for k in range(self.K):
            top_words = np.argsort(self.lambda_param[k])[-n_words:][::-1]
            topic_words.append([self.vocab[i] for i in top_words])
        return topic_words

    def plot_words_clouds_topic(self, topic_names, plt):
        for topic in range(self.K):
            # Get word probabilities for this topic
            word_probs = {self.vocab[i]: self.lambda_param[topic, i] 
                         for i in range(self.V)}
            
            print(f"\nAnalyzing Topic '{topic_names[topic]}':")
            print("Top words in this topic:")
            
            # Sort words by probability
            sorted_words = sorted(word_probs.items(), key=lambda x: x[1], reverse=True)
            for word, prob in sorted_words[:10]:
                print(f"  {word}: {prob:.4f}")
            
            if len(sorted_words) == 0:
                print(f"WARNING: Topic '{topic_names[topic]}' has no words!")
                continue
                
            # Create text for wordcloud
            wordcloud = WordCloud().generate_from_frequencies(word_probs)
            plt.figure()
            plt.imshow(wordcloud, interpolation='bilinear')
            plt.axis("off")
            plt.title("Topic #" + str(topic_names[topic]))
            plt.show()

# %%
import pandas as pd

input_file_path = "../data/preprocessed/combined_preprocessed_denoised.csv"
output_file_path = "../data/processed/lda_processed_round_1.csv"

# Read the CSV file into a pandas DataFrame
df_cleaned = load_data(input_file_path)

topics = df_cleaned['topic'].unique().tolist()
random.shuffle(topics)

output_df = pd.DataFrame(columns=['lda_processed_text'])

# %%
def pre_process_documents(documents):
    stop_words = set(stopwords.words('english'))
    processed_docs = []
    
    for doc in documents:
        if not isinstance(doc[0], str):  # Skip non-string entries
            continue
        # Convert to lowercase and split into words
        words = doc[0].split()
        # Remove special characters and numbers
        words = [re.sub(r'[^a-zA-Z]', '', word).lower() for word in words]
        # Remove empty strings and stop words
        words = [word for word in words if word and word not in stop_words]
        processed_docs.append(words)
    
    return processed_docs

# %%
batch_size = 4  # 4 tweets per topic
iterations = 250  # Number of iterations
num_topics = 4
max_iteration = 10
output_file_path = "../data/processed/lda_processed_round_2.csv"
# Perform batch training
for iteration in range(iterations):
    documents = []
    selected_topics = set()  # Keep track of selected topics

    while len(selected_topics) < num_topics:
        # Randomly select a topic not already chosen
        available_topics = list(set(topics) - selected_topics)
        if not available_topics:
            print(f"Not enough distinct topics available for iteration {iteration}")
            break
        topic = random.choice(available_topics)
        
        # Extract tweets for the topic
        topic_tweets = df_cleaned[df_cleaned['topic'] == topic]
        
        # Select tweets for this topic without the 'used_indices' condition
        selected_indices = random.sample(topic_tweets.index.tolist(), batch_size)
        tweets = topic_tweets.loc[selected_indices, 'processed_text'].tolist()
        documents.extend([[tweet] for tweet in tweets])
        selected_topics.add(topic)

    # If not enough topics were selected, skip this iteration
    if len(selected_topics) < num_topics:
        print(f"Skipping iteration {iteration} due to insufficient topics.")
        continue
    
    processed_docs = pre_process_documents(documents)
    vocab = sorted(list(set(word for doc in processed_docs for word in doc)))

    lda = LDA_VB(num_topics=num_topics, max_iter=max_iteration)
    lda.fit(processed_docs, vocab)

    topic_words = lda.get_topic_words(n_words=10)
    topic_strings = [' '.join(words) for words in topic_words]
    
    # Add the strings to the output DataFrame
    temp_df = pd.DataFrame({'lda_processed_text': topic_strings})

    # Concatenate the new rows to the output DataFrame
    output_df = pd.concat([output_df, temp_df], ignore_index=True)
# Out:
# Iteration 0: likelihood = -133.09230155056935
# Iteration 1: likelihood = -122.61708261174385
# Iteration 2: likelihood = -122.61708261547034
# Iteration 0: likelihood = -145.51732826629882
# Iteration 1: likelihood = -128.25917501696654
# Iteration 2: likelihood = -128.25917502432694
# Iteration 0: likelihood = -118.3620182257272
# Iteration 1: likelihood = -113.21603713993191
# Iteration 2: likelihood = -113.21603714182704
# Iteration 0: likelihood = -138.33151504264254
# Iteration 1: likelihood = -134.3157926881981
# Iteration 2: likelihood = -134.31579268962676
# Iteration 0: likelihood = -157.6260324080084
# Iteration 1: likelihood = -136.8896460514999
# Iteration 2: likelihood = -136.8896460588407
# Iteration 0: likelihood = -148.42310152738594
# Iteration 1: likelihood = -136.1533214363272
# Iteration 2: likelihood = -138.35006545838536
# Iteration 3: likelihood = -136.15332144233415
# Iteration 4: likelihood = -136.15332144370572
# Iteration 0: likelihood = -155.6392538834696
# Iteration 1: likelihood = -136.6972194041455
# Iteration 2: likelihood = -135.40844305824936
# Iteration 3: likelihood = -135.40844305979357
# Iteration 0: likelihood = -180.77025526615267
# Iteration 1: likelihood = -163.79305002588086
# Iteration 2: likelihood = -163.7930500313952
# Iteration 0: likelihood = -172.7953312200164
# Iteration 1: likelihood = -149.82323528897487
# Iteration 2: likelihood = -149.82323530007287
# Iteration 0: likelihood = -138.96893002579688
# Iteration 1: likelihood = -133.55067212585814
# Iteration 2: likelihood = -133.55067212858026
# Iteration 0: likelihood = -128.31954218402694
# Iteration 1: likelihood = -121.4343718530231
# Iteration 2: likelihood = -121.43437185588904
# Iteration 0: likelihood = -156.01629731127093
# Iteration 1: likelihood = -140.97386786822298
# Iteration 2: likelihood = -140.97386787350877
# Iteration 0: likelihood = -167.58045303148762
# Iteration 1: likelihood = -150.95104680466326
# Iteration 2: likelihood = -150.95104681058353
# Iteration 0: likelihood = -152.21329220238195
# Iteration 1: likelihood = -133.42307918315646
# Iteration 2: likelihood = -131.48636703682183
# Iteration 3: likelihood = -131.48636703733763
# Iteration 0: likelihood = -119.91101866101225
# Iteration 1: likelihood = -112.86489460551904
# Iteration 2: likelihood = -112.86489460814492
# Iteration 0: likelihood = -130.9875084693699
# Iteration 1: likelihood = -120.56608029508135
# Iteration 2: likelihood = -120.56608029938586
# Iteration 0: likelihood = -140.44064948605103
# Iteration 1: likelihood = -130.59839041635524
# Iteration 2: likelihood = -128.94016234367658
# Iteration 3: likelihood = -128.94016234525938
# Iteration 0: likelihood = -151.6206079018702
# Iteration 1: likelihood = -143.4389753235585
# Iteration 2: likelihood = -143.43897532758152
# Iteration 0: likelihood = -152.89848903259337
# Iteration 1: likelihood = -140.41115521649607
# Iteration 2: likelihood = -140.411155221903
# Iteration 0: likelihood = -139.5383042397188
# Iteration 1: likelihood = -129.12125465477408
# Iteration 2: likelihood = -126.52780465024773
# Iteration 3: likelihood = -126.5278046518404
# Iteration 0: likelihood = -144.71207845071095
# Iteration 1: likelihood = -135.72609024418506
# Iteration 2: likelihood = -135.72609024774832
# Iteration 0: likelihood = -135.1830650820537
# Iteration 1: likelihood = -125.15492030535525
# Iteration 2: likelihood = -125.15492030992507
# Iteration 0: likelihood = -150.426682353046
# Iteration 1: likelihood = -138.66476381578573
# Iteration 2: likelihood = -138.66476382065463
# Iteration 0: likelihood = -109.70598304712004
# Iteration 1: likelihood = -106.74557422270634
# Iteration 2: likelihood = -106.74557422344994
# Iteration 0: likelihood = -148.05414727193318
# Iteration 1: likelihood = -141.69180307957342
# Iteration 2: likelihood = -141.69180308178542
# Iteration 0: likelihood = -163.8340867030751
# Iteration 1: likelihood = -145.7172221209956
# Iteration 2: likelihood = -145.71722212664477
# Iteration 0: likelihood = -162.4851317979815
# Iteration 1: likelihood = -146.9582717643133
# Iteration 2: likelihood = -146.9582717702583
# Iteration 0: likelihood = -127.9982951195724
# Iteration 1: likelihood = -120.41422143838234
# Iteration 2: likelihood = -120.41422144171759
# Iteration 0: likelihood = -147.7347632715729
# Iteration 1: likelihood = -131.9304063766369
# Iteration 2: likelihood = -131.93040638343655
# Iteration 0: likelihood = -119.94082504875627
# Iteration 1: likelihood = -113.31981895254785
# Iteration 2: likelihood = -113.31981895503012
# Iteration 0: likelihood = -145.78268044513305
# Iteration 1: likelihood = -133.84772222011546
# Iteration 2: likelihood = -133.8477222251812
# Iteration 0: likelihood = -138.55190854895653
# Iteration 1: likelihood = -131.68321404553058
# Iteration 2: likelihood = -131.6832140480815
# Iteration 0: likelihood = -119.640292106603
# Iteration 1: likelihood = -117.54978594865943
# Iteration 2: likelihood = -117.54978595007113
# Iteration 0: likelihood = -167.96797793091795
# Iteration 1: likelihood = -145.36907850588295
# Iteration 2: likelihood = -145.36907851483195
# Iteration 0: likelihood = -155.67811378455693
# Iteration 1: likelihood = -140.8527305725191
# Iteration 2: likelihood = -142.5109586566537
# Iteration 3: likelihood = -140.85273057918593
# Iteration 4: likelihood = -140.8527305805944
# Iteration 0: likelihood = -140.03592548133733
# Iteration 1: likelihood = -131.9325752254184
# Iteration 2: likelihood = -131.932575228815
# Iteration 0: likelihood = -156.0453130756767
# Iteration 1: likelihood = -143.1825484877787
# Iteration 2: likelihood = -141.89377303202625
# Iteration 3: likelihood = -141.8937730335397
# Iteration 0: likelihood = -143.7569373191733
# Iteration 1: likelihood = -132.4206641561153
# Iteration 2: likelihood = -132.42066416030198
# Iteration 0: likelihood = -153.0693565540568
# Iteration 1: likelihood = -139.73027377909472
# Iteration 2: likelihood = -139.73027378482766
# Iteration 0: likelihood = -142.9604860748112
# Iteration 1: likelihood = -127.83055679700311
# Iteration 2: likelihood = -127.83055680441036
# Iteration 0: likelihood = -131.9858534258805
# Iteration 1: likelihood = -124.48118109277605
# Iteration 2: likelihood = -121.28149232252768
# Iteration 3: likelihood = -121.28149232208355
# Iteration 0: likelihood = -133.3795765239153
# Iteration 1: likelihood = -124.75527177590413
# Iteration 2: likelihood = -124.75527177923266
# Iteration 0: likelihood = -122.36988284148971
# Iteration 1: likelihood = -118.64693828884498
# Iteration 2: likelihood = -118.64693828969638
# Iteration 0: likelihood = -154.7450485716012
# Iteration 1: likelihood = -139.48933738223948
# Iteration 2: likelihood = -137.1090153433438
# Iteration 3: likelihood = -137.10901534373008
# Iteration 0: likelihood = -143.72698654515938
# Iteration 1: likelihood = -134.26351985291765
# Iteration 2: likelihood = -132.3717368428339
# Iteration 3: likelihood = -132.37173684361952
# Iteration 0: likelihood = -172.40466571673417
# Iteration 1: likelihood = -152.46422724316025
# Iteration 2: likelihood = -152.46422725109662
# Iteration 0: likelihood = -148.83238730995512
# Iteration 1: likelihood = -137.0379898744268
# Iteration 2: likelihood = -137.03798987838073
# Iteration 0: likelihood = -161.74532932455918
# Iteration 1: likelihood = -147.81115456852214
# Iteration 2: likelihood = -147.8111545733807
# Iteration 0: likelihood = -140.39765321763332
# Iteration 1: likelihood = -125.41318889373373
# Iteration 2: likelihood = -125.4131888998173
# Iteration 0: likelihood = -138.66842803285323
# Iteration 1: likelihood = -130.36035384175855
# Iteration 2: likelihood = -130.36035384512954
# Iteration 0: likelihood = -148.16157828955897
# Iteration 1: likelihood = -135.07088104405085
# Iteration 2: likelihood = -135.07088104891432
# Iteration 0: likelihood = -130.08547350351745
# Iteration 1: likelihood = -119.41501094048975
# Iteration 2: likelihood = -119.41501094543978
# Iteration 0: likelihood = -151.70513179494367
# Iteration 1: likelihood = -146.51233394678002
# Iteration 2: likelihood = -146.51233394899788
# Iteration 0: likelihood = -115.80724550312921
# Iteration 1: likelihood = -110.32931689441322
# Iteration 2: likelihood = -110.32931689686467
# Iteration 0: likelihood = -151.2178444891932
# Iteration 1: likelihood = -142.69609176194655
# Iteration 2: likelihood = -142.6960917652771
# Iteration 0: likelihood = -135.10910345056578
# Iteration 1: likelihood = -123.44593637261998
# Iteration 2: likelihood = -123.44593637608382
# Iteration 0: likelihood = -133.489388997209
# Iteration 1: likelihood = -122.25493950417865
# Iteration 2: likelihood = -122.25493950891199
# Iteration 0: likelihood = -118.56415322081129
# Iteration 1: likelihood = -110.73812210201467
# Iteration 2: likelihood = -110.73812210560372
# Iteration 0: likelihood = -136.72168197019914
# Iteration 1: likelihood = -128.13784125150644
# Iteration 2: likelihood = -128.1378412551609
# Iteration 0: likelihood = -130.76820982143877
# Iteration 1: likelihood = -123.31328033463541
# Iteration 2: likelihood = -123.31328033813996
# Iteration 0: likelihood = -130.72513297641657
# Iteration 1: likelihood = -125.47910484823532
# Iteration 2: likelihood = -125.4791048505399
# Iteration 0: likelihood = -162.60304106218973
# Iteration 1: likelihood = -152.4511671292211
# Iteration 2: likelihood = -149.8862471188276
# Iteration 3: likelihood = -149.88624712042093
# Iteration 0: likelihood = -135.21030890667853
# Iteration 1: likelihood = -119.51814353886337
# Iteration 2: likelihood = -119.5181435478807
# Iteration 0: likelihood = -126.63777482728996
# Iteration 1: likelihood = -119.32061988875692
# Iteration 2: likelihood = -119.32061989149345
# Iteration 0: likelihood = -167.9608149502335
# Iteration 1: likelihood = -151.79386250213528
# Iteration 2: likelihood = -151.79386250851235
# Iteration 0: likelihood = -141.51875987334884
# Iteration 1: likelihood = -132.21235444475025
# Iteration 2: likelihood = -132.21235444770753
# Iteration 0: likelihood = -162.61880249882017
# Iteration 1: likelihood = -147.93027343764138
# Iteration 2: likelihood = -147.93027344420491
# Iteration 0: likelihood = -168.26519844314896
# Iteration 1: likelihood = -148.5777483382766
# Iteration 2: likelihood = -148.57774834569724
# Iteration 0: likelihood = -151.4421023688308
# Iteration 1: likelihood = -137.78052310218743
# Iteration 2: likelihood = -137.7805231082342
# Iteration 0: likelihood = -169.91212637737686
# Iteration 1: likelihood = -150.56750721777945
# Iteration 2: likelihood = -150.5675072266117
# Iteration 0: likelihood = -145.67217178235018
# Iteration 1: likelihood = -135.77239813349416
# Iteration 2: likelihood = -133.51046952479092
# Iteration 3: likelihood = -133.51046952582087
# Iteration 0: likelihood = -160.5562553918766
# Iteration 1: likelihood = -145.47520474239474
# Iteration 2: likelihood = -143.2807949848179
# Iteration 3: likelihood = -143.2807949856762
# Iteration 0: likelihood = -121.22103031043514
# Iteration 1: likelihood = -114.42766963414378
# Iteration 2: likelihood = -114.42766963767896
# Iteration 0: likelihood = -140.4678142308398
# Iteration 1: likelihood = -133.33965868330836
# Iteration 2: likelihood = -133.33965868634579
# Iteration 0: likelihood = -155.95407004765005
# Iteration 1: likelihood = -148.8179385238585
# Iteration 2: likelihood = -146.81572880658038
# Iteration 3: likelihood = -146.81572880676543
# Iteration 0: likelihood = -142.24449653329384
# Iteration 1: likelihood = -132.8124220183895
# Iteration 2: likelihood = -132.8124220225915
# Iteration 0: likelihood = -129.20541069513058
# Iteration 1: likelihood = -118.43297088461091
# Iteration 2: likelihood = -118.43297088884431
# Iteration 0: likelihood = -134.90446076033788
# Iteration 1: likelihood = -120.66561775185532
# Iteration 2: likelihood = -120.66561775822254
# Iteration 0: likelihood = -150.52594402755827
# Iteration 1: likelihood = -139.96811549080647
# Iteration 2: likelihood = -139.96811549417922
# Iteration 0: likelihood = -127.10261964719851
# Iteration 1: likelihood = -120.18217139828722
# Iteration 2: likelihood = -118.59577316911393
# Iteration 3: likelihood = -118.59577316956107
# Iteration 0: likelihood = -117.26044015436322
# Iteration 1: likelihood = -114.16500761116258
# Iteration 2: likelihood = -114.16500761414447
# Iteration 0: likelihood = -133.24733723087223
# Iteration 1: likelihood = -123.7778917525297
# Iteration 2: likelihood = -123.7778917565742
# Iteration 0: likelihood = -156.1103213271705
# Iteration 1: likelihood = -142.53386941383852
# Iteration 2: likelihood = -142.5338694199381
# Iteration 0: likelihood = -153.41062863799505
# Iteration 1: likelihood = -138.22853833729204
# Iteration 2: likelihood = -138.2285383434889
# Iteration 0: likelihood = -164.94113774570795
# Iteration 1: likelihood = -158.26737770371238
# Iteration 2: likelihood = -155.8392721428448
# Iteration 3: likelihood = -155.8392721435963
# Iteration 0: likelihood = -137.5517045323589
# Iteration 1: likelihood = -123.41584871433125
# Iteration 2: likelihood = -123.4158487197861
# Iteration 0: likelihood = -146.1137641082601
# Iteration 1: likelihood = -130.39125731696234
# Iteration 2: likelihood = -130.3912573228316
# Iteration 0: likelihood = -175.53751116321513
# Iteration 1: likelihood = -156.9683937233227
# Iteration 2: likelihood = -156.96839372950558
# Iteration 0: likelihood = -164.3045247255479
# Iteration 1: likelihood = -153.56693667536058
# Iteration 2: likelihood = -153.56693668026062
# Iteration 0: likelihood = -148.54988530038113
# Iteration 1: likelihood = -134.02934265700247
# Iteration 2: likelihood = -134.02933905083748
# Iteration 0: likelihood = -129.62892304114249
# Iteration 1: likelihood = -120.7216587528148
# Iteration 2: likelihood = -120.72165875739249
# Iteration 0: likelihood = -168.8662813595022
# Iteration 1: likelihood = -153.79237755508038
# Iteration 2: likelihood = -151.2922176974841
# Iteration 3: likelihood = -151.29221769888431
# Iteration 0: likelihood = -122.14490479976136
# Iteration 1: likelihood = -114.10007792714865
# Iteration 2: likelihood = -114.10007792995896
# Iteration 0: likelihood = -142.96775444962833
# Iteration 1: likelihood = -133.34024024207997
# Iteration 2: likelihood = -133.3402402457102
# Iteration 0: likelihood = -147.28526792182095
# Iteration 1: likelihood = -132.80323047699082
# Iteration 2: likelihood = -132.80323048200495
# Iteration 0: likelihood = -151.50766594327825
# Iteration 1: likelihood = -139.0584731952139
# Iteration 2: likelihood = -139.05847319935597
# Iteration 0: likelihood = -165.12786624639725
# Iteration 1: likelihood = -148.4720305980238
# Iteration 2: likelihood = -148.4720306056142
# Iteration 0: likelihood = -143.4393747341699
# Iteration 1: likelihood = -129.0962469919079
# Iteration 2: likelihood = -129.0962469977501
# Iteration 0: likelihood = -149.62698984152115
# Iteration 1: likelihood = -142.5229334254831
# Iteration 2: likelihood = -142.52293342846656
# Iteration 0: likelihood = -152.09172555815942
# Iteration 1: likelihood = -136.88358863332266
# Iteration 2: likelihood = -136.88358864004377
# Iteration 0: likelihood = -156.0590478251299
# Iteration 1: likelihood = -142.76511406235062
# Iteration 2: likelihood = -142.76511406750905
# Iteration 0: likelihood = -136.66910526779301
# Iteration 1: likelihood = -129.43013290002025
# Iteration 2: likelihood = -129.43013290257196
# Iteration 0: likelihood = -176.05262073865603
# Iteration 1: likelihood = -160.51813039096302
# Iteration 2: likelihood = -160.51813039654252
# Iteration 0: likelihood = -129.38312533846715
# Iteration 1: likelihood = -122.58002067672608
# Iteration 2: likelihood = -122.58002068007178
# Iteration 0: likelihood = -172.4255229838152
# Iteration 1: likelihood = -159.28279696355952
# Iteration 2: likelihood = -159.28279696889152
# Iteration 0: likelihood = -166.74042497411222
# Iteration 1: likelihood = -146.76713334806018
# Iteration 2: likelihood = -146.76713335537485
# Iteration 0: likelihood = -137.27337406173078
# Iteration 1: likelihood = -124.84157190529383
# Iteration 2: likelihood = -124.84157190925066
# Iteration 0: likelihood = -137.53197885337124
# Iteration 1: likelihood = -123.26209779773247
# Iteration 2: likelihood = -123.26209780312598
# Iteration 0: likelihood = -158.230125328502
# Iteration 1: likelihood = -141.13965783130507
# Iteration 2: likelihood = -141.1396578384083
# Iteration 0: likelihood = -142.53285165800784
# Iteration 1: likelihood = -125.42061922598488
# Iteration 2: likelihood = -125.42061923470037
# Iteration 0: likelihood = -163.7283955487948
# Iteration 1: likelihood = -147.42718992107896
# Iteration 2: likelihood = -147.4271899275517
# Iteration 0: likelihood = -140.11687593474022
# Iteration 1: likelihood = -133.20446052123904
# Iteration 2: likelihood = -133.2044605234354
# Iteration 0: likelihood = -147.5703284337392
# Iteration 1: likelihood = -135.26386532689253
# Iteration 2: likelihood = -135.26386533182213
# Iteration 0: likelihood = -160.97956423524116
# Iteration 1: likelihood = -147.502819330619
# Iteration 2: likelihood = -147.50281933619408
# Iteration 0: likelihood = -145.19480562910792
# Iteration 1: likelihood = -137.9722161531937
# Iteration 2: likelihood = -136.68344388238182
# Iteration 3: likelihood = -136.683443883895
# Iteration 0: likelihood = -149.7578541692637
# Iteration 1: likelihood = -139.38919664432646
# Iteration 2: likelihood = -139.3891966483743
# Iteration 0: likelihood = -150.3295143079369
# Iteration 1: likelihood = -134.00976540276065
# Iteration 2: likelihood = -134.00976540780005
# Iteration 0: likelihood = -134.48559559508305
# Iteration 1: likelihood = -124.40659441116257
# Iteration 2: likelihood = -124.4065944138618
# Iteration 0: likelihood = -163.5811054938252
# Iteration 1: likelihood = -150.49621907988998
# Iteration 2: likelihood = -149.69454915052097
# Iteration 3: likelihood = -149.6945491505555
# Iteration 0: likelihood = -108.54224257339038
# Iteration 1: likelihood = -106.63033782813105
# Iteration 2: likelihood = -106.63033782881392
# Iteration 0: likelihood = -140.48167694368883
# Iteration 1: likelihood = -129.54222928954727
# Iteration 2: likelihood = -129.54222929510016
# Iteration 0: likelihood = -147.69625471964795
# Iteration 1: likelihood = -134.69552414625295
# Iteration 2: likelihood = -134.69552415170142
# Iteration 0: likelihood = -140.98451108016272
# Iteration 1: likelihood = -129.85369085532173
# Iteration 2: likelihood = -129.85369086024454
# Iteration 0: likelihood = -149.6817678944834
# Iteration 1: likelihood = -136.09677617781966
# Iteration 2: likelihood = -136.0967761831845
# Iteration 0: likelihood = -154.19273867679456
# Iteration 1: likelihood = -141.33533227057765
# Iteration 2: likelihood = -141.3353322756942
# Iteration 0: likelihood = -158.0930299845233
# Iteration 1: likelihood = -139.88758174540942
# Iteration 2: likelihood = -139.88758175211143
# Iteration 0: likelihood = -115.50866794846081
# Iteration 1: likelihood = -109.12767136275085
# Iteration 2: likelihood = -109.1276713657236
# Iteration 0: likelihood = -154.71367350935537
# Iteration 1: likelihood = -143.83555187027812
# Iteration 2: likelihood = -143.835551875016
# Iteration 0: likelihood = -122.58305691401844
# Iteration 1: likelihood = -118.27830277658542
# Iteration 2: likelihood = -118.27830277849436
# Iteration 0: likelihood = -125.31576456365323
# Iteration 1: likelihood = -115.18876004627265
# Iteration 2: likelihood = -115.18876005021468
# Iteration 0: likelihood = -145.0349174056561
# Iteration 1: likelihood = -133.70734439466364
# Iteration 2: likelihood = -133.80992822278762
# Iteration 3: likelihood = -131.1660734359942
# Iteration 4: likelihood = -131.16607343720608
# Iteration 0: likelihood = -141.5473577488754
# Iteration 1: likelihood = -129.62998680365592
# Iteration 2: likelihood = -129.62998680831026
# Iteration 0: likelihood = -155.59148826890387
# Iteration 1: likelihood = -145.55786432264887
# Iteration 2: likelihood = -145.5578643266949
# Iteration 0: likelihood = -150.77377370566987
# Iteration 1: likelihood = -145.82334450573862
# Iteration 2: likelihood = -145.82334450680398
# Iteration 0: likelihood = -150.49484742631526
# Iteration 1: likelihood = -134.56346565126705
# Iteration 2: likelihood = -134.56346565600433
# Iteration 0: likelihood = -129.9029305160731
# Iteration 1: likelihood = -124.48873463568857
# Iteration 2: likelihood = -124.48873463683408
# Iteration 0: likelihood = -169.76019957902832
# Iteration 1: likelihood = -146.44815872053434
# Iteration 2: likelihood = -146.4481587288986
# Iteration 0: likelihood = -158.15214225927122
# Iteration 1: likelihood = -137.6934725409417
# Iteration 2: likelihood = -137.69347254924043
# Iteration 0: likelihood = -144.7184894867481
# Iteration 1: likelihood = -133.42381696195756
# Iteration 2: likelihood = -133.4238169659403
# Iteration 0: likelihood = -105.3992040102837
# Iteration 1: likelihood = -99.97812866451204
# Iteration 2: likelihood = -99.97812866690919
# Iteration 0: likelihood = -147.13658007708304
# Iteration 1: likelihood = -137.6499517102463
# Iteration 2: likelihood = -137.64995171239966
# Iteration 0: likelihood = -141.59340712835336
# Iteration 1: likelihood = -131.5227331090771
# Iteration 2: likelihood = -131.52273311163282
# Iteration 0: likelihood = -168.54132806512587
# Iteration 1: likelihood = -150.6758175865267
# Iteration 2: likelihood = -150.67581759436953
# Iteration 0: likelihood = -125.63145346354206
# Iteration 1: likelihood = -119.50678666549499
# Iteration 2: likelihood = -119.50678666846997
# Iteration 0: likelihood = -154.66988881442458
# Iteration 1: likelihood = -143.66066383204728
# Iteration 2: likelihood = -143.66066383624818
# Iteration 0: likelihood = -126.09334947409447
# Iteration 1: likelihood = -120.8030746418368
# Iteration 2: likelihood = -120.80307464293774
# Iteration 0: likelihood = -116.09136568515594
# Iteration 1: likelihood = -111.00193138937979
# Iteration 2: likelihood = -112.29074759672496
# Iteration 3: likelihood = -111.00193139113719
# Iteration 4: likelihood = -111.00193139268964
# Iteration 0: likelihood = -144.4150109326262
# Iteration 1: likelihood = -133.01772576661887
# Iteration 2: likelihood = -133.01772577282512
# Iteration 0: likelihood = -142.60959217750067
# Iteration 1: likelihood = -128.19194688981443
# Iteration 2: likelihood = -128.19194689573465
# Iteration 0: likelihood = -143.70026391450398
# Iteration 1: likelihood = -134.86811023963685
# Iteration 2: likelihood = -134.86811024301664
# Iteration 0: likelihood = -148.60421023752446
# Iteration 1: likelihood = -135.30283346757668
# Iteration 2: likelihood = -135.30283347320113
# Iteration 0: likelihood = -156.13224344005584
# Iteration 1: likelihood = -142.79941404032377
# Iteration 2: likelihood = -142.7994140457785
# Iteration 0: likelihood = -205.29302041452488
# Iteration 1: likelihood = -179.80879611274406
# Iteration 2: likelihood = -179.8087961225006
# Iteration 0: likelihood = -120.90057849702163
# Iteration 1: likelihood = -114.34901616519143
# Iteration 2: likelihood = -114.34901616821799
# Iteration 0: likelihood = -165.75336211745443
# Iteration 1: likelihood = -147.95653052193026
# Iteration 2: likelihood = -147.95653052874638
# Iteration 0: likelihood = -153.39775299990208
# Iteration 1: likelihood = -142.29168018524825
# Iteration 2: likelihood = -142.291680189999
# Iteration 0: likelihood = -147.11464195615903
# Iteration 1: likelihood = -136.49980365267834
# Iteration 2: likelihood = -136.49980365710383
# Iteration 0: likelihood = -125.25315916489352
# Iteration 1: likelihood = -116.74976220242542
# Iteration 2: likelihood = -116.74976220494183
# Iteration 0: likelihood = -126.8418540948071
# Iteration 1: likelihood = -119.73196621247861
# Iteration 2: likelihood = -119.73196621534812
# Iteration 0: likelihood = -145.27883476707493
# Iteration 1: likelihood = -133.7572526327412
# Iteration 2: likelihood = -133.75725263792668
# Iteration 0: likelihood = -144.31850226437808
# Iteration 1: likelihood = -133.70154180090069
# Iteration 2: likelihood = -133.70154180558004
# Iteration 0: likelihood = -157.68172113548866
# Iteration 1: likelihood = -142.58382198364345
# Iteration 2: likelihood = -142.58382199069746
# Iteration 0: likelihood = -137.10183262120808
# Iteration 1: likelihood = -123.02315286686735
# Iteration 2: likelihood = -123.02315287147837
# Iteration 0: likelihood = -118.33625613363735
# Iteration 1: likelihood = -106.15387971283813
# Iteration 2: likelihood = -107.44268462700113
# Iteration 3: likelihood = -106.15387971922303
# Iteration 4: likelihood = -106.153879720741
# Iteration 0: likelihood = -172.31322237072692
# Iteration 1: likelihood = -152.22411148944767
# Iteration 2: likelihood = -152.22411149853576
# Iteration 0: likelihood = -138.28397349483916
# Iteration 1: likelihood = -128.43058963671785
# Iteration 2: likelihood = -128.4305896405443
# Iteration 0: likelihood = -127.95396741730319
# Iteration 1: likelihood = -121.22941338999769
# Iteration 2: likelihood = -121.22941339256104
# Iteration 0: likelihood = -156.32899069276922
# Iteration 1: likelihood = -145.64981094212524
# Iteration 2: likelihood = -145.64981094754674
# Iteration 0: likelihood = -129.36043017621532
# Iteration 1: likelihood = -117.51052912915249
# Iteration 2: likelihood = -117.51052913407538
# Iteration 0: likelihood = -147.71633819942556
# Iteration 1: likelihood = -136.2081271879475
# Iteration 2: likelihood = -136.20812719208914
# Iteration 0: likelihood = -159.05821841865384
# Iteration 1: likelihood = -143.87384498893343
# Iteration 2: likelihood = -143.8738449937973
# Iteration 0: likelihood = -141.82371690188575
# Iteration 1: likelihood = -130.02943119740493
# Iteration 2: likelihood = -128.74064597007126
# Iteration 3: likelihood = -128.74064597172682
# Iteration 0: likelihood = -111.70309304690662
# Iteration 1: likelihood = -105.60591653339593
# Iteration 2: likelihood = -105.60591653823721
# Iteration 0: likelihood = -116.63816610026173
# Iteration 1: likelihood = -113.83677165990187
# Iteration 2: likelihood = -113.83677166101086
# Iteration 0: likelihood = -161.61126248570096
# Iteration 1: likelihood = -146.43460346340729
# Iteration 2: likelihood = -146.43460346936303
# Iteration 0: likelihood = -148.34699276485583
# Iteration 1: likelihood = -134.85141786067035
# Iteration 2: likelihood = -133.56263841773256
# Iteration 3: likelihood = -133.56263841930073
# Iteration 0: likelihood = -153.6656034851836
# Iteration 1: likelihood = -142.28872724489554
# Iteration 2: likelihood = -142.28872724864948
# Iteration 0: likelihood = -134.84534791552596
# Iteration 1: likelihood = -128.21115305626466
# Iteration 2: likelihood = -128.2111530585245
# Iteration 0: likelihood = -158.8894843253091
# Iteration 1: likelihood = -137.27880044118683
# Iteration 2: likelihood = -137.2786447840239
# Iteration 3: likelihood = -137.2786447840239
# Iteration 0: likelihood = -140.95021987691868
# Iteration 1: likelihood = -128.11504662108916
# Iteration 2: likelihood = -128.11504662602755
# Iteration 0: likelihood = -135.6027301753265
# Iteration 1: likelihood = -129.4049245796187
# Iteration 2: likelihood = -126.86074121279825
# Iteration 3: likelihood = -126.86074121353593
# Iteration 0: likelihood = -129.47499814791686
# Iteration 1: likelihood = -120.6389541208532
# Iteration 2: likelihood = -120.6389541248233
# Iteration 0: likelihood = -119.17536523390815
# Iteration 1: likelihood = -111.68216381428633
# Iteration 2: likelihood = -111.68216381639563
# Iteration 0: likelihood = -169.81890351015505
# Iteration 1: likelihood = -151.83888328217265
# Iteration 2: likelihood = -151.83888328882338
# Iteration 0: likelihood = -177.12486781128342
# Iteration 1: likelihood = -148.77497308250085
# Iteration 2: likelihood = -148.774973094965
# Iteration 0: likelihood = -145.19496977888952
# Iteration 1: likelihood = -131.73694814504688
# Iteration 2: likelihood = -131.73694815146794
# Iteration 0: likelihood = -148.95874244269584
# Iteration 1: likelihood = -140.88986374786577
# Iteration 2: likelihood = -140.88986375039838
# Iteration 0: likelihood = -137.59777766755414
# Iteration 1: likelihood = -131.0531700763946
# Iteration 2: likelihood = -131.05317007734828
# Iteration 0: likelihood = -153.83087637208277
# Iteration 1: likelihood = -140.67151470471632
# Iteration 2: likelihood = -140.67151471098882
# Iteration 0: likelihood = -148.91893386121313
# Iteration 1: likelihood = -141.7255392644534
# Iteration 2: likelihood = -141.72553926651628
# Iteration 0: likelihood = -163.46535341821982
# Iteration 1: likelihood = -152.09083320232145
# Iteration 2: likelihood = -149.0072349790407
# Iteration 3: likelihood = -149.00723498005271
# Iteration 0: likelihood = -162.26451769301337
# Iteration 1: likelihood = -143.86231412007797
# Iteration 2: likelihood = -143.06867430139098
# Iteration 3: likelihood = -141.03891691020496
# Iteration 4: likelihood = -141.03891691026453
# Iteration 0: likelihood = -130.07347320939124
# Iteration 1: likelihood = -124.8975288659791
# Iteration 2: likelihood = -122.45081943366007
# Iteration 3: likelihood = -122.45081943488344
# Iteration 0: likelihood = -125.48678785834812
# Iteration 1: likelihood = -117.37937257597744
# Iteration 2: likelihood = -117.37937257842901
# Iteration 0: likelihood = -157.52114324985655
# Iteration 1: likelihood = -139.8470578877004
# Iteration 2: likelihood = -139.8470578949788
# Iteration 0: likelihood = -132.92339102572086
# Iteration 1: likelihood = -122.77533261523287
# Iteration 2: likelihood = -122.77533261835244
# Iteration 0: likelihood = -145.95724923565027
# Iteration 1: likelihood = -130.26692698024422
# Iteration 2: likelihood = -130.26692698660278
# Iteration 0: likelihood = -149.0566499731958
# Iteration 1: likelihood = -137.0904676763205
# Iteration 2: likelihood = -137.09046768023674
# Iteration 0: likelihood = -121.72990172424781
# Iteration 1: likelihood = -117.2211101984709
# Iteration 2: likelihood = -117.22111020023179
# Iteration 0: likelihood = -124.93577841580138
# Iteration 1: likelihood = -119.1486503183319
# Iteration 2: likelihood = -119.14865032039754
# Iteration 0: likelihood = -152.35911861714143
# Iteration 1: likelihood = -144.59366917944072
# Iteration 2: likelihood = -142.13320464795302
# Iteration 3: likelihood = -142.13320464935384
# Iteration 0: likelihood = -154.3099282975067
# Iteration 1: likelihood = -144.7319839065612
# Iteration 2: likelihood = -144.7319839095557
# Iteration 0: likelihood = -163.947550881025
# Iteration 1: likelihood = -146.06141961021373
# Iteration 2: likelihood = -146.0614196182031
# Iteration 0: likelihood = -141.42155524969468
# Iteration 1: likelihood = -130.97495911627684
# Iteration 2: likelihood = -130.97495911990305
# Iteration 0: likelihood = -152.60114812968314
# Iteration 1: likelihood = -137.4978569166548
# Iteration 2: likelihood = -137.49785692276325
# Iteration 0: likelihood = -129.8817022387295
# Iteration 1: likelihood = -120.88145429970344
# Iteration 2: likelihood = -120.88145430342666
# Iteration 0: likelihood = -137.63555162136674
# Iteration 1: likelihood = -130.04868678669175
# Iteration 2: likelihood = -130.0486867896434
# Iteration 0: likelihood = -134.13410617746223
# Iteration 1: likelihood = -128.4750908722182
# Iteration 2: likelihood = -128.47509087396642
# Iteration 0: likelihood = -119.0862325097041
# Iteration 1: likelihood = -114.39540107851514
# Iteration 2: likelihood = -111.9977360290433
# Iteration 3: likelihood = -111.9977360302608
# Iteration 0: likelihood = -155.88860553625358
# Iteration 1: likelihood = -148.2596267630132
# Iteration 2: likelihood = -148.25962676497824
# Iteration 0: likelihood = -147.9885740698561
# Iteration 1: likelihood = -135.5150064778473
# Iteration 2: likelihood = -135.51500648242268
# Iteration 0: likelihood = -127.80064846343393
# Iteration 1: likelihood = -120.97006457705463
# Iteration 2: likelihood = -118.54772666383522
# Iteration 3: likelihood = -119.83653785878798
# Iteration 4: likelihood = -118.54772666715914
# Iteration 5: likelihood = -118.54772666867864
# Iteration 0: likelihood = -138.25935993223658
# Iteration 1: likelihood = -124.91661690881152
# Iteration 2: likelihood = -126.20542164456076
# Iteration 3: likelihood = -124.91661691532246
# Iteration 4: likelihood = -124.91661691684037
# Iteration 0: likelihood = -161.98061445266805
# Iteration 1: likelihood = -148.11587222338886
# Iteration 2: likelihood = -148.11587222944274
# Iteration 0: likelihood = -115.57766948374358
# Iteration 1: likelihood = -112.02733492748399
# Iteration 2: likelihood = -110.73852420133932
# Iteration 3: likelihood = -110.73852420200811
# Iteration 0: likelihood = -160.3045006590607
# Iteration 1: likelihood = -153.16170532800353
# Iteration 2: likelihood = -153.1617053295023
# Iteration 0: likelihood = -131.75807654109983
# Iteration 1: likelihood = -116.8298940705637
# Iteration 2: likelihood = -116.82989407827847
# Iteration 0: likelihood = -141.05474725903082
# Iteration 1: likelihood = -133.16335905722238
# Iteration 2: likelihood = -134.45216971470902
# Iteration 3: likelihood = -133.16335906236114
# Iteration 4: likelihood = -133.16335906386138
# Iteration 0: likelihood = -131.94896865649778
# Iteration 1: likelihood = -124.58910976918295
# Iteration 2: likelihood = -124.58910977194851
# Iteration 0: likelihood = -136.21885127198192
# Iteration 1: likelihood = -120.95841356518875
# Iteration 2: likelihood = -120.95841357337282
# Iteration 0: likelihood = -144.1277110159022
# Iteration 1: likelihood = -139.56236338981148
# Iteration 2: likelihood = -139.56236339191403
# Iteration 0: likelihood = -125.77005666346064
# Iteration 1: likelihood = -122.40674090088126
# Iteration 2: likelihood = -122.92149282958573
# Iteration 3: likelihood = -123.04373633755279
# Iteration 4: likelihood = -119.58969125967597
# Iteration 5: likelihood = -119.58969125550439
# Iteration 0: likelihood = -153.2279065823458
# Iteration 1: likelihood = -146.3103644787227
# Iteration 2: likelihood = -146.31036448063102
# Iteration 0: likelihood = -159.21684662255805
# Iteration 1: likelihood = -149.60768195151945
# Iteration 2: likelihood = -149.60768195386774
# Iteration 0: likelihood = -136.78646011291838
# Iteration 1: likelihood = -125.84227057110397
# Iteration 2: likelihood = -125.8422705740755
# Iteration 0: likelihood = -151.06247994466904
# Iteration 1: likelihood = -142.2883405676484
# Iteration 2: likelihood = -142.28834057091726
# Iteration 0: likelihood = -130.5011731678002
# Iteration 1: likelihood = -120.18968903030965
# Iteration 2: likelihood = -120.18968903473021
# Iteration 0: likelihood = -148.0643109943708
# Iteration 1: likelihood = -137.8388047030902
# Iteration 2: likelihood = -137.83880471001225
# Iteration 0: likelihood = -142.67900885114085
# Iteration 1: likelihood = -130.9275421398158
# Iteration 2: likelihood = -130.92754214440887
# Iteration 0: likelihood = -156.7746465774701
# Iteration 1: likelihood = -145.60229745109018
# Iteration 2: likelihood = -145.60229745513854
# Iteration 0: likelihood = -146.67841109936887
# Iteration 1: likelihood = -133.4060256453319
# Iteration 2: likelihood = -133.40602564837397
# Iteration 0: likelihood = -154.9172525443575
# Iteration 1: likelihood = -140.7192234991789
# Iteration 2: likelihood = -140.71922350394445
# Iteration 0: likelihood = -189.67520314324952
# Iteration 1: likelihood = -164.27970903117574
# Iteration 2: likelihood = -164.2797090422563
# Iteration 0: likelihood = -154.78433872293684
# Iteration 1: likelihood = -140.30094113489648
# Iteration 2: likelihood = -140.30094113940154
# Iteration 0: likelihood = -147.08843731370433
# Iteration 1: likelihood = -133.42398694110457
# Iteration 2: likelihood = -133.4239869464537
# Iteration 0: likelihood = -151.23764089532867
# Iteration 1: likelihood = -141.53128391931034
# Iteration 2: likelihood = -141.53128392251185
# Iteration 0: likelihood = -157.5132405967754
# Iteration 1: likelihood = -138.3910947342514
# Iteration 2: likelihood = -138.39109474122384
# Iteration 0: likelihood = -133.0612856759999
# Iteration 1: likelihood = -119.6970769853449
# Iteration 2: likelihood = -119.69707699248404
# Iteration 0: likelihood = -125.89869308425139
# Iteration 1: likelihood = -117.41514763022359
# Iteration 2: likelihood = -117.41514763385385
# Iteration 0: likelihood = -163.3176326084375
# Iteration 1: likelihood = -143.15511537834738
# Iteration 2: likelihood = -143.1551153861386
# Iteration 0: likelihood = -151.2476434486134
# Iteration 1: likelihood = -144.0007898280739
# Iteration 2: likelihood = -144.00078982988884
# Iteration 0: likelihood = -168.96123705807003
# Iteration 1: likelihood = -151.75275148446076
# Iteration 2: likelihood = -151.7527514917109
# Iteration 0: likelihood = -137.30435445715202
# Iteration 1: likelihood = -131.46640498516996
# Iteration 2: likelihood = -131.46640498754078
# Iteration 0: likelihood = -143.83247166298588
# Iteration 1: likelihood = -126.207918653121
# Iteration 2: likelihood = -126.2079186604611
# Iteration 0: likelihood = -148.78382619429684
# Iteration 1: likelihood = -135.9883425215025
# Iteration 2: likelihood = -135.98834252665313
# Iteration 0: likelihood = -155.37958202810123
# Iteration 1: likelihood = -146.62484498969107
# Iteration 2: likelihood = -146.6248449927624
# Iteration 0: likelihood = -167.366340572837
# Iteration 1: likelihood = -153.25412158349286
# Iteration 2: likelihood = -152.79169315769172
# Iteration 3: likelihood = -152.791693157716
# Iteration 0: likelihood = -143.9564653056824
# Iteration 1: likelihood = -128.89160364392072
# Iteration 2: likelihood = -128.89160365003397
# Iteration 0: likelihood = -138.4407249406119
# Iteration 1: likelihood = -126.8920886737192
# Iteration 2: likelihood = -126.89208867975671
# Iteration 0: likelihood = -124.27789928443397
# Iteration 1: likelihood = -115.24877503648183
# Iteration 2: likelihood = -115.2487750428711

# %%
output_df.to_csv(output_file_path, index=False)

print(f"LDA batch processing completed. Results saved to {output_file_path}")# Save the output DataFrame to a CSV file
# Out:
# LDA batch processing completed. Results saved to ../data/processed/lda_processed_round_2.csv
